# %% [markdown]
# # Pertemuan 3 — NumPy, Pandas, dan Data Understanding
#
# Notebook hasil hands-on pertemuan 3. Pastikan `data.csv` sudah ada di folder yang sama (atau sudah diupload ke Colab) sebelum menjalankan cell yang membacanya. Ikuti tiap cell berurutan dari atas ke bawah. Detail penjelasan tiap langkah ada di `README.md` pertemuan ini.

# %% [markdown]
# ## NumPy vs Pandas: Buat Apa Masing-Masing di Dunia Data Analyst?
#
# Sebelum masuk ke kode, kenalan dulu sama dua library yang dipakai sepanjang pertemuan ini.
#
# **NumPy (Numerical Python)**
# - Library dasar buat komputasi numerik di Python — isinya struktur data **array** dan operasi matematis yang cepat.
# - Dipakai data analyst buat hitung-hitungan angka dalam jumlah besar sekaligus (operasi vectorized), tanpa nulis loop manual satu-satu.
# - Array NumPy isinya harus **satu tipe data yang sama** (semua angka, misalnya), dan tidak punya nama kolom/baris — cuma deretan angka polos.
#
# **Pandas**
# - Library buat mengolah **data tabular** (tabel) — dibangun di atas NumPy, jadi performanya tetap cepat, tapi lebih ramah dipakai buat data beneran.
# - Dipakai data analyst buat baca file (CSV, Excel), bersihkan data, filter, gabungkan tabel, sampai ringkas jadi insight.
# - Struktur datanya (Series, DataFrame) boleh campur tipe data per kolom (satu kolom teks, kolom lain angka, kolom lain tanggal), dan punya nama kolom + index — persis seperti tabel Excel.
#
# **Perbedaannya secara singkat:**
#
# | | NumPy | Pandas |
# |---|---|---|
# | Struktur data | Array (angka polos, satu tipe) | Series/DataFrame (tabel, boleh campur tipe) |
# | Cocok buat | Komputasi angka murni, matematika/statistik dasar | Data terstruktur: baca CSV, bersihkan, filter, analisis |
# | Ada nama kolom? | Tidak | Ya (dan index baris) |
# | Dipakai kapan | Di balik layar Pandas, atau perhitungan angka murni | Sehari-hari buat kerja dengan dataset asli |
#
# Intinya: **NumPy itu mesinnya, Pandas itu yang dipakai langsung.** Data analyst jarang menyentuh NumPy secara langsung untuk data tabular — tapi tiap kali menjalankan operasi Pandas (`df["harga"] * 2`, `df["harga"].mean()`, dst), di baliknya NumPy yang bekerja supaya prosesnya cepat.

# %% [markdown]
# ## 1. Operasi Vectorized dengan NumPy

# %%
import numpy as np

angka = np.array([10, 20, 30, 40])
print(angka * 2)
# Out:
# [20 40 60 80]

# %% [markdown]
# ## 2. Series Sederhana

# %%
import pandas as pd

harga_produk = pd.Series([150000, 220000, 75000], name="harga")
print(harga_produk)
# Out:
# 0    150000
# 1    220000
# 2     75000
# Name: harga, dtype: int64

# %% [markdown]
# ## 3. DataFrame Manual dari Dictionary

# %%
data_manual = {
    "nama_produk": ["Mouse", "Kaos Polos", "Novel Fiksi"],
    "kategori": ["Elektronik", "Fashion", "Buku"],
    "harga": [150000, 75000, 68000],
}
df_manual = pd.DataFrame(data_manual)
display(df_manual)
# Out:
#    nama_produk    kategori   harga
# 0        Mouse  Elektronik  150000
# 1   Kaos Polos     Fashion   75000
# 2  Novel Fiksi        Buku   68000

# %% [markdown]
# ## 4. Membaca data.csv
#
# Pastikan `data.csv` sudah diupload ke Colab (panel Files di kiri) sebelum menjalankan cell ini.

# %%
df = pd.read_csv("data.csv")
print(type(df))
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (133, 8)

# %% [markdown]
# ## 5. head() dan tail()

# %% [markdown]
# head : 0-10 , tail : 10-0

# %%
display(df.head())

# %%
display(df.tail(3))

# %% [markdown]
# ## 6. shape

# %% [markdown]
# ngecek baris dan kolom

# %%
df.shape
# Out:
# (133, 8)

# %% [markdown]
# ## 7. df.info(): Cek Struktur dan Tipe Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_pesanan   133 non-null    int64
#  1   tanggal      133 non-null    object
#  2   nama_produk  133 non-null    object
#  3   kategori     133 non-null    object
#  4   harga        127 non-null    float64
#  5   jumlah       133 non-null    int64
#  6   wilayah      133 non-null    object
#  7   modal        133 non-null    int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 8.4+ KB

# %% [markdown]
# ## 8. df.describe(): Statistik Cepat

# %%
display(df.describe())
# Out:
#         id_pesanan         harga      jumlah         modal
# count   133.000000  1.270000e+02  133.000000  1.330000e+02
# mean   1065.661654  2.627953e+05    3.007519  1.527669e+05
# std      37.657525  1.206160e+06    1.489846  8.284011e+05
# min    1001.000000  1.300000e+04    1.000000  8.000000e+03
# 25%    1033.000000  4.050000e+04    2.000000  2.700000e+04
# 50%    1066.000000  7.300000e+04    3.000000  4.700000e+04
# 75%    1098.000000  1.680000e+05    4.000000  1.300000e+05
# max    1130.000000  1.050000e+07    5.000000  9.600000e+06

# %% [markdown]
# ## 9. Statistik Satu Angka

# %%
print("Harga termurah:", df["harga"].min())
print("Harga termahal:", df["harga"].max())
print("Rata-rata harga:", df["harga"].mean())
print("Median harga:", df["harga"].median())
print("Kuartil 1 (Q1):", df["harga"].quantile(0.25))
print("Kuartil 3 (Q3):", df["harga"].quantile(0.75))
print("Total jumlah barang terjual:", df["jumlah"].sum())
# Out:
# Harga termurah: 13000.0
# Harga termahal: 10500000.0
# Rata-rata harga: 262795.2755905512
# Median harga: 73000.0
# Kuartil 1 (Q1): 40500.0
# Kuartil 3 (Q3): 168000.0
# Total jumlah barang terjual: 400

# %% [markdown]
# Sekarang cari **produk**-nya, bukan cuma angkanya.

# %%
produk_termahal = df.loc[df["harga"].idxmax()]
produk_termurah = df.loc[df["harga"].idxmin()]

print("Produk termahal:")
display(produk_termahal[["nama_produk", "kategori", "harga"]])

print("\nProduk termurah:")
display(produk_termurah[["nama_produk", "kategori", "harga"]])

# %% [markdown]
# ## 10. Cek Data Kosong: isna().sum()

# %%
display(df.isna().sum())

# %% [markdown]
# ## 11. Cek Duplikat: duplicated().sum()

# %%
print(df.duplicated().sum())
# Out:
# 3

# %% [markdown]
# Angka itu baru jumlahnya -- buat lihat **baris mana** yang duplikat:

# %%
baris_duplikat = df[df.duplicated(keep=False)].sort_values("id_pesanan")
print(baris_duplikat.shape)
display(baris_duplikat)
# Out:
# (6, 8)
#      id_pesanan     tanggal       nama_produk    kategori    harga  jumlah  \
# 28         1029  2026-01-11  Keripik Singkong     Makanan  20000.0       5
# 130        1029  2026-01-11  Keripik Singkong     Makanan  20000.0       5
# 70         1071  2026-02-14     Buku Motivasi        Buku  68000.0       4
# 131        1071  2026-02-14     Buku Motivasi        Buku  68000.0       4
# 117        1118  2026-02-25           Charger  Elektronik  89000.0       1
# 132        1118  2026-02-25           Charger  Elektronik  89000.0       1
#
#       wilayah  modal
# 28    Jakarta  13000
# 130   Jakarta  13000
# 70   Surabaya  40000
# 131  Surabaya  40000
# 117  Surabaya  53000
# 132  Surabaya  53000

# %% [markdown]
# ## 12. Memilih Satu Kolom

# %%
display(df[["nama_produk"]].head())
# Out:
#          nama_produk
# 0              Mouse
# 1              Mouse
# 2  Speaker Bluetooth
# 3        Novel Fiksi
# 4        Matras Yoga

# %% [markdown]
# ## 13. Memilih Beberapa Kolom

# %%
display(df[["nama_produk", "kategori", "harga"]].head())
# Out:
#          nama_produk    kategori     harga
# 0              Mouse  Elektronik  150000.0
# 1              Mouse  Elektronik  155000.0
# 2  Speaker Bluetooth  Elektronik       NaN
# 3        Novel Fiksi        Buku   62000.0
# 4        Matras Yoga    Olahraga  121000.0

# %% [markdown]
# ## 14. Filter Baris: Harga di Atas 100.000

# %%
produk_mahal = df[df["harga"] > 100000]
print(produk_mahal.shape)
display(produk_mahal.head())
# Out:
# (51, 8)
#     id_pesanan     tanggal        nama_produk    kategori     harga  jumlah  \
# 0         1001  2026-01-05              Mouse  Elektronik  150000.0       2
# 1         1002  2026-01-29              Mouse  Elektronik  155000.0       2
# 4         1005  2026-02-23        Matras Yoga    Olahraga  121000.0       5
# 8         1009  2026-02-18  Speaker Bluetooth  Elektronik  317000.0       1
# 10        1011  2026-02-07         Tas Ransel     Fashion  153000.0       2
#
#     wilayah   modal
# 0   Jakarta   95000
# 1   Bandung  113000
# 4   Bandung   71000
# 8   Jakarta  179000
# 10  Jakarta   94000

# %% [markdown]
# Satu kondisi doang kadang belum cukup — coba gabungan kondisi (AND/OR/NOT).

# %%
# AND (&) -- harga di atas 100rb DAN kategorinya Elektronik
elektronik_mahal = df[(df["harga"] > 100000) & (df["kategori"] == "Elektronik")]
print("Elektronik mahal:", elektronik_mahal.shape)
display(elektronik_mahal[["nama_produk", "kategori", "harga"]].head())

# Satu kondisi lain -- semua produk yang terjual di wilayah tertentu
produk_jakarta = df[df["wilayah"] == "Jakarta"]
print("Produk di Jakarta:", produk_jakarta.shape)
display(produk_jakarta[["nama_produk", "wilayah"]].head())

# NOT (!= atau ~) -- semua produk SELAIN kategori Buku
bukan_buku = df[df["kategori"] != "Buku"]
print("Bukan kategori Buku:", bukan_buku.shape)
display(bukan_buku[["nama_produk", "kategori"]].head())
# Out:
# Elektronik mahal: (18, 8)
#           nama_produk    kategori     harga
# 0               Mouse  Elektronik  150000.0
# 1               Mouse  Elektronik  155000.0
# 8   Speaker Bluetooth  Elektronik  317000.0
# 16           Keyboard  Elektronik  234000.0
# 27         Power Bank  Elektronik  174000.0
# Produk di Jakarta: (32, 8)
#           nama_produk  wilayah
# 0               Mouse  Jakarta
# 6    Madu Hutan 250ml  Jakarta
# 8   Speaker Bluetooth  Jakarta
# 10         Tas Ransel  Jakarta
# 12       Jaket Hoodie  Jakarta
# Bukan kategori Buku: (103, 8)
#          nama_produk    kategori
# 0              Mouse  Elektronik
# 1              Mouse  Elektronik
# 2  Speaker Bluetooth  Elektronik
# 4        Matras Yoga    Olahraga
# 6   Madu Hutan 250ml     Makanan

# %% [markdown]
# ## 15. Feature Engineering: Kolom nilai_penjualan
#
# `nilai_penjualan` belum ada di `data.csv` — dibuat dari kolom `harga` dan `jumlah` yang sudah ada.

# %%
df["nilai_penjualan"] = df["harga"] * df["jumlah"]
display(df[["nama_produk", "harga", "jumlah", "nilai_penjualan"]].head())
# Out:
#          nama_produk     harga  jumlah  nilai_penjualan
# 0              Mouse  150000.0       2         300000.0
# 1              Mouse  155000.0       2         310000.0
# 2  Speaker Bluetooth       NaN       5              NaN
# 3        Novel Fiksi   62000.0       2         124000.0
# 4        Matras Yoga  121000.0       5         605000.0

# %% [markdown]
# ## 16. Menghitung Untung/Rugi per Transaksi

# %%
df["untung"] = (df["harga"] - df["modal"]) * df["jumlah"]
display(df[["nama_produk", "harga", "modal", "jumlah", "untung"]].head())

produk_paling_untung = df.loc[df["untung"].idxmax()]
produk_paling_rugi = df.loc[df["untung"].idxmin()]

print("Produk paling untung:")
display(produk_paling_untung[["nama_produk", "kategori", "harga", "modal", "jumlah", "untung"]])

print("\nProduk paling rugi:")
display(produk_paling_rugi[["nama_produk", "kategori", "harga", "modal", "jumlah", "untung"]])

print("\nJumlah baris untung:", (df["untung"] > 0).sum())
print("Jumlah baris rugi:", (df["untung"] < 0).sum())
# Out:
#          nama_produk     harga   modal  jumlah    untung
# 0              Mouse  150000.0   95000       2  110000.0
# 1              Mouse  155000.0  113000       2   84000.0
# 2  Speaker Bluetooth       NaN  196000       5       NaN
# 3        Novel Fiksi   62000.0   39000       2   46000.0
# 4        Matras Yoga  121000.0   71000       5  250000.0
# Produk paling untung:
# nama_produk    Sepatu Sneakers
# kategori               Fashion
# harga                8900000.0
# modal                   245000
# jumlah                       4
# untung              34620000.0
# Name: 40, dtype: object
# Produk paling rugi:
# nama_produk    Raket Badminton
# kategori              Olahraga
# harga                 268000.0
# modal                   319000
# jumlah                       3
# untung               -153000.0
# Name: 75, dtype: object
# Jumlah baris untung: 124
# Jumlah baris rugi: 3

# %% [markdown]
# ## 17. Latihan Gabungan

# %%
print("5 baris pertama:")
display(df.head())

print("\njumlah baris & kolom:", df.shape)

print("\nkolom numerik:")
print(df.select_dtypes(include="number").columns.tolist())

print("\nfilter kategori Buku:")
print(df[df["kategori"] == "Buku"].shape)

# %% [markdown]
# ## 18. (Bonus) Menggabungkan Dua Tabel dengan merge()
#
# Coba dulu di tabel kecil biar keempat jenis join-nya keliatan jelas.

# %%
pelanggan = pd.DataFrame({
    "id_pelanggan": [1, 2, 3],
    "nama": ["Andi", "Budi", "Citra"],
})

pesanan = pd.DataFrame({
    "id_pelanggan": [1, 2, 4],
    "produk": ["Mouse", "Kaos", "Novel"],
})

display(pelanggan)
display(pesanan)

for cara in ["inner", "left", "right", "outer"]:
    print(f"\n--- how={cara} ---")
    display(pd.merge(pelanggan, pesanan, on="id_pelanggan", how=cara))
# Out:
#    id_pelanggan   nama
# 0             1   Andi
# 1             2   Budi
# 2             3  Citra
#    id_pelanggan produk
# 0             1  Mouse
# 1             2   Kaos
# 2             4  Novel
# --- how=inner ---
#    id_pelanggan  nama produk
# 0             1  Andi  Mouse
# 1             2  Budi   Kaos
# --- how=left ---
#    id_pelanggan   nama produk
# 0             1   Andi  Mouse
# 1             2   Budi   Kaos
# 2             3  Citra    NaN
# --- how=right ---
#    id_pelanggan  nama produk
# 0             1  Andi  Mouse
# 1             2  Budi   Kaos
# 2             4   NaN  Novel
# --- how=outer ---
#    id_pelanggan   nama produk
# 0             1   Andi  Mouse
# 1             2   Budi   Kaos
# 2             3  Citra    NaN
# 3             4    NaN  Novel

# %% [markdown]
# Sekarang terapkan ke data asli -- tapi dites dulu di potongan kecil (4 baris) biar hasil tiap join masih kebaca penuh sebagai tabel, sebelum diterapkan ke semua 133 baris.

# %%
diskon_kategori = pd.DataFrame({
    "kategori": ["Elektronik", "Fashion", "Makanan", "Olahraga"],
    "diskon_persen": [10, 15, 5, 20],
})
display(diskon_kategori)

# Contoh kecil: 2 produk Elektronik (kategorinya ADA di diskon_kategori)
# + 2 produk Buku (kategorinya TIDAK ADA di diskon_kategori)
bersih = df[df["harga"].notna()]
contoh = bersih[bersih["kategori"].isin(["Elektronik", "Buku"])].head(4)[["nama_produk", "kategori", "harga"]]
display(contoh)

for cara in ["inner", "left", "right", "outer"]:
    print(f"\n--- how={cara} ---")
    display(pd.merge(contoh, diskon_kategori, on="kategori", how=cara))

# %% [markdown]
# Sekarang terapkan ke keseluruhan data (133 baris) -- cukup lihat ukurannya, tabelnya kepanjangan buat ditampilkan penuh.

# %%
for cara in ["inner", "left", "right", "outer"]:
    hasil = pd.merge(df, diskon_kategori, on="kategori", how=cara)
    print(f"{cara.upper()} JOIN shape:", hasil.shape)

df_gabung = pd.merge(df, diskon_kategori, on="kategori", how="left")
display(df_gabung[df_gabung["kategori"] == "Buku"][["nama_produk", "kategori", "diskon_persen"]].head(3))

# %% [markdown]
# ## 19. (Bonus) Menyimpan Hasil ke File CSV Baru

# %%
df_gabung.to_csv("data_dengan_diskon.csv", index=False)
print("Tersimpan sebagai data_dengan_diskon.csv")

# %% [markdown]
# ## Cheatsheet: NumPy & Pandas
#
# Ringkasan semua perintah yang dipakai hari ini, biar gampang dicari lagi pas lupa.
#
# ### NumPy
#
# | Perintah | Buat apa |
# |---|---|
# | `np.array([...])` | Bikin array dari list biasa |
# | `array * 2` | Operasi vectorized -- semua elemen dikali sekaligus, tanpa loop |
#
# ### Pandas: Bikin & Baca Data
#
# | Perintah | Buat apa |
# |---|---|
# | `pd.Series([...], name="...")` | Bikin satu kolom data berlabel |
# | `pd.DataFrame({...})` | Bikin tabel dari dictionary |
# | `pd.read_csv("nama_file.csv")` | Baca file CSV jadi DataFrame |
# | `df.to_csv("nama_file.csv", index=False)` | Simpan DataFrame jadi file CSV baru |
#
# ### Pandas: Mengintip & Memahami Data (Data Understanding)
#
# | Perintah | Buat apa |
# |---|---|
# | `df.head()` | Lihat 5 baris pertama (default) |
# | `df.tail(n)` | Lihat `n` baris terakhir |
# | `df.shape` | `(jumlah baris, jumlah kolom)` |
# | `df.info()` | Struktur: nama kolom, tipe data, jumlah non-null |
# | `df.describe()` | Statistik cepat (count/mean/std/min/25%/50%/75%/max) buat kolom angka |
# | `df.isna().sum()` | Jumlah data kosong (`NaN`) per kolom |
# | `df.duplicated().sum()` | Jumlah baris yang duplikat (cuma dihitung, bukan baris aslinya) |
# | `df.duplicated(keep=False)` | Tandai SEMUA baris yang punya kembaran (asli + salinan) |
#
# ### Pandas: Statistik Satu Kolom
#
# | Perintah | Buat apa |
# |---|---|
# | `df["kolom"].min()` / `.max()` | Nilai terkecil / terbesar |
# | `df["kolom"].mean()` / `.median()` | Rata-rata / nilai tengah |
# | `df["kolom"].quantile(0.25)` / `.quantile(0.75)` | Kuartil 1 (Q1) / Kuartil 3 (Q3) |
# | `df["kolom"].sum()` | Total semua nilai di kolom |
# | `df["kolom"].idxmax()` / `.idxmin()` | Index baris dengan nilai terbesar / terkecil |
# | `df.loc[index]` | Ambil satu baris lengkap berdasarkan index-nya |
#
# ### Pandas: Memilih & Menyaring Data
#
# | Perintah | Buat apa |
# |---|---|
# | `df["kolom"]` | Ambil satu kolom -> Series |
# | `df[["a", "b"]]` | Ambil beberapa kolom sekaligus -> DataFrame |
# | `df[df["kolom"] > angka]` | Filter baris berdasarkan satu kondisi |
# | `&` | AND -- gabung 2+ kondisi, semuanya harus benar (wajib dikurung tiap kondisi) |
# | `\|` | OR -- gabung 2+ kondisi, salah satu benar sudah cukup |
# | `~` atau `!=` | NOT -- membalik/menegasikan kondisi |
# | `df["baru"] = df["a"] * df["b"]` | Bikin kolom baru dari kolom yang sudah ada (feature engineering) |
# | `df.select_dtypes(include="number")` | Ambil cuma kolom-kolom yang bertipe angka |
#
# ### Pandas: Menggabungkan Tabel (Join)
#
# | Perintah | Buat apa |
# |---|---|
# | `pd.merge(a, b, on="kolom", how="inner")` | Cuma baris yang kuncinya ada di KEDUA tabel |
# | `how="left"` | Semua baris tabel kiri dipertahankan, yang tidak match diisi `NaN` |
# | `how="right"` | Semua baris tabel kanan dipertahankan, yang tidak match diisi `NaN` |
# | `how="outer"` | Semua baris dari kedua tabel, yang tidak match diisi `NaN` |

# %% [markdown]
# ## Selesai
#
# Notebook ini menutup pertemuan 3. Data yang dipakai (`data.csv`) masih punya beberapa "gejala" yang belum dibereskan: 6 harga kosong, 3 baris duplikat, kolom tanggal belum bertipe tanggal, dan ada outlier di kolom harga — semua itu jadi bahan pertemuan 4. Lanjut ke `kuis-latihan-3.md`/`pilgan-3.md` untuk latihan mandiri, atau ke pertemuan 4 untuk data cleaning dan EDA.
